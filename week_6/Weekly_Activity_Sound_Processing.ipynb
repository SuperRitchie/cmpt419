# %% [markdown]
# *Credit: This notebook was prepared by
#  Payam Jome Yazdian (Rosie Lab)*

# %% [markdown]
# ## Import Dependencies

# %%
# !pip install soundfile
# !pip install librosa
import numpy as np
import scipy.io.wavfile as wavef
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd
from IPython.display import Audio

#from google.colab import drive
import soundfile as sf
# Out:
# Requirement already satisfied: soundfile in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from soundfile) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0->soundfile) (2.21)
# Requirement already satisfied: librosa in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.26.2)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.12.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.4.1.post1)
# Requirement already satisfied: joblib>=0.14 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\flame\appdata\roaming\python\python312\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (0.59.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (4.10.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\flame\appdata\roaming\python\python312\site-packages (from pooch>=1.0->librosa) (4.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\flame\appdata\roaming\python\python312\site-packages (from pooch>=1.0->librosa) (23.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.20.0->librosa) (3.3.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\flame\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)

# %% [markdown]
# # Task 1. Generate a sound:
# A single-frequency sound wave with frequency f, maximum amplitude A, and phase θ is represented by the sine function
#
# y=Asin(2πfx+θ)
#
# where x is time and y is the amplitude of the sound wave at time x.
#
# Given the formalization above, complete the following function *mkwave* so as to generate a sine wave signal with a specific duration, amplitude, frequency (Hz), phase, and sampling rate.
#
# Play around with the parameters and answer the following questions in Canvas:
#
# 1.   What is the relationship between frequency (Hz) and the perception of the resulting sound?
# 2.   What is the relationship between the length of a sound and sampling rate?
# 3.   How does sampling rate affect the sound?
# 4.   How does phase affect the sound?
#
# For more information about sampling rate please check [this](https://en.wikipedia.org/wiki/Compact_Disc_Digital_Audio).

# %%
def mkwave(duration_sec, amp, freq_hz, phase, sampling_rate=44100):
    x = np.arange(0.0, duration_sec, 1.0/sampling_rate) # start, stop, step
    y = amp * np.sin(2 * np.pi * freq_hz * x + phase)
    # ...
    return y

target_freq_hz = 440
sampling_rate = 44100
duration = 1.0
amplitude = 1.0
phase = 0

wav = mkwave(duration, amplitude, target_freq_hz, phase, sampling_rate)

#Plot signal
plt.figure(1)
plt.figure(figsize=(14, 5))
plt.title("Wave Signal")
plt.plot(wav)
plt.show()

#Play audio
ipd.display(ipd.Audio(data=wav, rate=sampling_rate))

# Write to a file
wavef.write("example.wav", sampling_rate, wav)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Task 2. Visualize a wave signal
# - In this part you must implement a part of code which visualizes the following plots of generated signal by previous section.
# -- spectrum
#
# Hint: You may use the librosa's [feature](https://librosa.org/doc/main/feature.html) class.
#
# Post a picture of your spectrogram in Canvas, and answer the following question.
#
# What does the spectrogram allow us to see, with respect to the parameters you set in Step 1?

# %%
# plot spectogram:
# ...

# Load the WAV file
wav, _ = librosa.load('ooo.wav') #, sr=None)

# Use librosa's feature class to get the spectrogram
D = librosa.amplitude_to_db(np.abs(librosa.stft(wav)), ref=np.max)
plt.figure()
plt.figure(figsize=(14, 5))
librosa.display.specshow(D, sr=sampling_rate, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.show()

# %% [markdown]
# # Task 3. Plot the spectrum of 2 wave files of your choice
#
# Find or record at least 2 short [affect bursts](https://www.sciencedirect.com/science/article/pii/S016763930200078X?casa_token=bdo4xIj0JXYAAAAA:zJkZiqBgxB9MJbNtZyBPBD5kVZzfpS8MUXJGAlLmhyPHrXtu0_uimWsfEZKFc9rnJhHX83FtZw), such as "oooOOOOoo" or "ah!" or "awwww", representing an emotion(s). For example, what sound could you use to express disgust or awe?
#
# ### Load an audio file from Google Drive:
# This allows you to work in CoLab without needing to upload your data at each runtime
# -  First, open the file browser on the left hand side. It will show a **'Mount Drive'** button similar to the Google Drive Icon.
# - Once clicked, you'll see a permissions prompt to mount Drive, and then your Drive files will be present.
# - Afterward, look for your intended file, right-click on that, and click "Copy path".
# - Finally, paste it in your code (inspired from the above) instead of *myfile.wav*
#
# ### OR, load an audio file locally
# - If using Jupyter Notebook offline, simply paste the path to the file
#
# Note: You can download a sample from https://freesound.org/ or record your own.
#
# Post the picture of your spectrums in Canvas and answer the following questions.
#
# 1. What sounds did you choose?
# 2. Describe what you see in the spectrum(s). What formants do you see?
# 3. Any other comments on this activity.
